# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd ./drive/My\ Drive/NLP-Model-Demo/RNN_Translator_Demo/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: './drive/My Drive/NLP-Model-Demo/RNN_Translator_Demo/'
# /content/drive/My Drive/NLP-Model-Demo/RNN_Translator_Demo

# %%
from data_prepare import *

# %%
from models import Plain_RNN, Criterion

# %%
import importlib

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
device = 'cuda'

# %%
# Test data_prepare
train_en_w, train_cn_w = load_data(train_file)
dev_en_w, dev_cn_w = load_data(dev_file)

en2idx, idx2en = build_vocab(train_en_w)
cn2idx, idx2cn = build_vocab(train_cn_w)

train_en, train_cn = sentences2idx(train_en_w, train_cn_w, en2idx, cn2idx, len_sort=False)
dev_en, dev_cn = sentences2idx(dev_en_w, dev_cn_w, en2idx, cn2idx, len_sort=False)

# %%
batch_size = 64
train_data = gen_examples(train_en, train_cn, batch_size)
dev_data = gen_examples(dev_en, dev_cn, batch_size)
print('num of batchs:', len(train_data))
print('maxlen of No.200 batch:', train_data[200][0][0].size)
# Out:
# num of batchs: 228
# maxlen of No.200 batch: 16

# %%
# choose No.200 batch
batch_x = torch.from_numpy(train_data[200][0]).long().to(device)
batch_x_len = torch.from_numpy(train_data[200][1]).long().to(device)
print('idx sentences:\n', batch_x, '\n', batch_x.shape)  # 64, 20
print('len of sentences:\n', batch_x_len, '\n', batch_x_len.shape)  # 64
# Out:
# idx sentences:
#  tensor([[   2,   25,   10,  ...,    1,    1,    1],
#         [   2,    5,   22,  ...,    1,    1,    1],
#         [   2,   61,   28,  ...,    1,    1,    1],
#         ...,
#         [   2,   87,   14,  ...,    1,    1,    1],
#         [   2,   28, 2193,  ...,    1,    1,    1],
#         [   2,    5,  236,  ...,    1,    1,    1]], device='cuda:0')
#  torch.Size([64, 16])
# len of sentences:
#  tensor([ 7,  7,  9,  6,  9,  9, 10, 15, 10, 10,  7,  9, 14,  9, 10, 10,  9,  6,
#          8, 11,  9, 10,  9,  8, 10, 16, 15,  9,  9,  7,  9,  9,  6,  8,  9, 10,
#         10, 10, 11, 15,  7, 11,  8, 15,  7,  6, 10,  9,  7, 10,  7,  7,  9,  8,
#         10,  6, 10, 11,  7,  9,  6, 10,  9,  6], device='cuda:0')
#  torch.Size([64])

# %%
# Test Encoder
importlib.reload(Plain_RNN)
M = Plain_RNN.PlainEncoder(len(en2idx), 100)
M.to(device)
output, hidden = M(batch_x, batch_x_len)
print(output.shape, hidden.shape)
# Out:
# torch.Size([64, 16, 100]) torch.Size([1, 64, 100])

# %%
dropout = 0.2
hidden_size=100
encoder = Plain_RNN.PlainEncoder(len(en2idx), hidden_size, dropout)
decoder = Plain_RNN.PlainDecoder(len(en2idx), hidden_size, dropout)

model = Plain_RNN.PlainSeq2Seq(encoder, decoder)
model = model.to(device)

loss_fn = Criterion.LanguageModelCriterion()
optimizer = torch.optim.Adam(model.parameters())

# %%
def train(model, data, num_epochs):
    model.train() # 训练模式
    for epoch in range(num_epochs):
        total_num_words = total_loss = 0.
        for it, (mb_x, mb_x_len, mb_y, mb_y_len) in enumerate(data):
            mb_x = torch.from_numpy(mb_x).to(device).long()
            mb_x_len = torch.from_numpy(mb_x_len).to(device).long()
            mb_input = torch.from_numpy(mb_y[:, :-1]).to(device).long() # EOS之前
            mb_output = torch.from_numpy(mb_y[:, 1:]).to(device).long() # BOS之后
            mb_y_len = torch.from_numpy(mb_y_len - 1).to(device).long()
            mb_y_len[mb_y_len <= 0] = 1
            mb_pred, attn = model(mb_x, mb_x_len, mb_input, mb_y_len)
            # [mb_y_len.max()]->[1, mb_y_len.max()]
            mb_out_mask = torch.arange(mb_y_len.max().item(), device=device)[None, :] < mb_y_len[:, None]
            mb_out_mask = mb_out_mask.float()
            # (pre, target, mask)
            # mb_output是句子单词的索引
            loss = loss_fn(mb_pred, mb_output, mb_out_mask)
            num_words = torch.sum(mb_y_len).item()
            total_loss += loss.item() * num_words
            total_num_words += num_words
            # 更新模型
            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.)
            optimizer.step()
            if it % 100 == 0:
                print("Epoch: ", epoch, 'iteration', it, 'loss:', loss.item())
                # print("Epoch", epoch, "Training loss", total_loss / total_num_words)
            if epoch % 5 == 0:
                # evaluate(model, dev_data)
                torch.save(model.state_dict(), 'translate_model.pt')

# %%
train(model, train_data, num_epochs=100)
# Out:
# Epoch:  0 iteration 0 loss: 5.07315731048584
# Epoch:  0 iteration 100 loss: 4.649954795837402
# Epoch:  0 iteration 200 loss: 4.615468502044678
# Epoch:  1 iteration 0 loss: 4.459018230438232
# Epoch:  1 iteration 100 loss: 4.126104354858398
# Epoch:  1 iteration 200 loss: 4.121497631072998
# Epoch:  2 iteration 0 loss: 4.008650779724121
# Epoch:  2 iteration 100 loss: 3.795247793197632
# Epoch:  2 iteration 200 loss: 3.8154125213623047
# Epoch:  3 iteration 0 loss: 3.7629566192626953
# Epoch:  3 iteration 100 loss: 3.593043088912964
# Epoch:  3 iteration 200 loss: 3.6101157665252686
# Epoch:  4 iteration 0 loss: 3.5578391551971436
# Epoch:  4 iteration 100 loss: 3.4303364753723145
# Epoch:  4 iteration 200 loss: 3.4314322471618652
# Epoch:  5 iteration 0 loss: 3.4152586460113525
# Epoch:  5 iteration 100 loss: 3.295196294784546
# Epoch:  5 iteration 200 loss: 3.277961254119873
# Epoch:  6 iteration 0 loss: 3.33132004737854
# Epoch:  6 iteration 100 loss: 3.2044777870178223
# Epoch:  6 iteration 200 loss: 3.167145013809204
# Epoch:  7 iteration 0 loss: 3.250743865966797
# Epoch:  7 iteration 100 loss: 3.093032121658325
# Epoch:  7 iteration 200 loss: 3.0819592475891113
# Epoch:  8 iteration 0 loss: 3.1459293365478516
# Epoch:  8 iteration 100 loss: 3.0014612674713135
# Epoch:  8 iteration 200 loss: 2.983013391494751
# Epoch:  9 iteration 0 loss: 3.093113422393799
# Epoch:  9 iteration 100 loss: 2.9293251037597656
# Epoch:  9 iteration 200 loss: 2.911607503890991
# Epoch:  10 iteration 0 loss: 2.9765658378601074
# Epoch:  10 iteration 100 loss: 2.8884942531585693
# Epoch:  10 iteration 200 loss: 2.8339669704437256
# Epoch:  11 iteration 0 loss: 2.9622809886932373
# Epoch:  11 iteration 100 loss: 2.815192937850952
# Epoch:  11 iteration 200 loss: 2.7671148777008057
# Epoch:  12 iteration 0 loss: 2.9450864791870117
# Epoch:  12 iteration 100 loss: 2.775716543197632
# Epoch:  12 iteration 200 loss: 2.6775457859039307
# Epoch:  13 iteration 0 loss: 2.838005304336548
# Epoch:  13 iteration 100 loss: 2.710613250732422
# Epoch:  13 iteration 200 loss: 2.6131513118743896
# Epoch:  14 iteration 0 loss: 2.8314740657806396
# Epoch:  14 iteration 100 loss: 2.6673147678375244
# Epoch:  14 iteration 200 loss: 2.5810437202453613
# Epoch:  15 iteration 0 loss: 2.757449150085449
# Epoch:  15 iteration 100 loss: 2.6331889629364014
# Epoch:  15 iteration 200 loss: 2.5345864295959473
# Epoch:  16 iteration 0 loss: 2.784982204437256
# Epoch:  16 iteration 100 loss: 2.592496395111084
# Epoch:  16 iteration 200 loss: 2.5052671432495117
# Epoch:  17 iteration 0 loss: 2.7106356620788574
# Epoch:  17 iteration 100 loss: 2.5327341556549072
# Epoch:  17 iteration 200 loss: 2.4647696018218994
# Epoch:  18 iteration 0 loss: 2.655982255935669
# Epoch:  18 iteration 100 loss: 2.5272927284240723
# Epoch:  18 iteration 200 loss: 2.4348368644714355
# Epoch:  19 iteration 0 loss: 2.604675531387329
# Epoch:  19 iteration 100 loss: 2.4799487590789795
# Epoch:  19 iteration 200 loss: 2.376260995864868
# Epoch:  20 iteration 0 loss: 2.579803228378296
# Epoch:  20 iteration 100 loss: 2.4274885654449463
# Epoch:  20 iteration 200 loss: 2.345391035079956
# Epoch:  21 iteration 0 loss: 2.5477781295776367
# Epoch:  21 iteration 100 loss: 2.4032833576202393
# Epoch:  21 iteration 200 loss: 2.301989793777466
# Epoch:  22 iteration 0 loss: 2.541649341583252
# Epoch:  22 iteration 100 loss: 2.404888153076172
# Epoch:  22 iteration 200 loss: 2.273810386657715
# Epoch:  23 iteration 0 loss: 2.496945381164551
# Epoch:  23 iteration 100 loss: 2.3867781162261963
# Epoch:  23 iteration 200 loss: 2.2257072925567627
# Epoch:  24 iteration 0 loss: 2.4539856910705566
# Epoch:  24 iteration 100 loss: 2.3628058433532715
# Epoch:  24 iteration 200 loss: 2.2282047271728516
# Epoch:  25 iteration 0 loss: 2.4474685192108154
# Epoch:  25 iteration 100 loss: 2.3320999145507812
# Epoch:  25 iteration 200 loss: 2.184612989425659
# Epoch:  26 iteration 0 loss: 2.4449656009674072
# Epoch:  26 iteration 100 loss: 2.3026108741760254
# Epoch:  26 iteration 200 loss: 2.1399166584014893
# Epoch:  27 iteration 0 loss: 2.408290386199951
# Epoch:  27 iteration 100 loss: 2.306396961212158
# Epoch:  27 iteration 200 loss: 2.1198019981384277
# Epoch:  28 iteration 0 loss: 2.3648581504821777
# Epoch:  28 iteration 100 loss: 2.281916618347168
# Epoch:  28 iteration 200 loss: 2.117022752761841
# Epoch:  29 iteration 0 loss: 2.384854555130005
# Epoch:  29 iteration 100 loss: 2.2327208518981934
# Epoch:  29 iteration 200 loss: 2.0545132160186768
# Epoch:  30 iteration 0 loss: 2.333085060119629
# Epoch:  30 iteration 100 loss: 2.2348995208740234
# Epoch:  30 iteration 200 loss: 2.0594964027404785
# Epoch:  31 iteration 0 loss: 2.326662063598633
# Epoch:  31 iteration 100 loss: 2.1698286533355713
# Epoch:  31 iteration 200 loss: 2.0472519397735596
# Epoch:  32 iteration 0 loss: 2.283905267715454
# Epoch:  32 iteration 100 loss: 2.192535400390625
# Epoch:  32 iteration 200 loss: 1.9957185983657837
# Epoch:  33 iteration 0 loss: 2.25822377204895
# Epoch:  33 iteration 100 loss: 2.201080322265625
# Epoch:  33 iteration 200 loss: 2.0123157501220703
# Epoch:  34 iteration 0 loss: 2.2594008445739746
# Epoch:  34 iteration 100 loss: 2.1597158908843994
# Epoch:  34 iteration 200 loss: 1.9716095924377441
# Epoch:  35 iteration 0 loss: 2.2568376064300537
# Epoch:  35 iteration 100 loss: 2.1672027111053467
# Epoch:  35 iteration 200 loss: 1.959474802017212
# Epoch:  36 iteration 0 loss: 2.2467775344848633
# Epoch:  36 iteration 100 loss: 2.115081310272217
# Epoch:  36 iteration 200 loss: 1.9464232921600342
# Epoch:  37 iteration 0 loss: 2.2221412658691406
# Epoch:  37 iteration 100 loss: 2.086202383041382
# Epoch:  37 iteration 200 loss: 1.9449468851089478
# Epoch:  38 iteration 0 loss: 2.2130250930786133
# Epoch:  38 iteration 100 loss: 2.049837589263916
# Epoch:  38 iteration 200 loss: 1.8872736692428589
# Epoch:  39 iteration 0 loss: 2.184776782989502
# Epoch:  39 iteration 100 loss: 2.0618553161621094
# Epoch:  39 iteration 200 loss: 1.8952703475952148
# Epoch:  40 iteration 0 loss: 2.1898226737976074
# Epoch:  40 iteration 100 loss: 2.0386462211608887
# Epoch:  40 iteration 200 loss: 1.852181077003479
# Epoch:  41 iteration 0 loss: 2.1745407581329346
# Epoch:  41 iteration 100 loss: 2.0372204780578613
# Epoch:  41 iteration 200 loss: 1.8933607339859009
# Epoch:  42 iteration 0 loss: 2.10418438911438
# Epoch:  42 iteration 100 loss: 2.0037755966186523
# Epoch:  42 iteration 200 loss: 1.8659197092056274
# Epoch:  43 iteration 0 loss: 2.102436065673828
# Epoch:  43 iteration 100 loss: 2.0198490619659424
# Epoch:  43 iteration 200 loss: 1.8512976169586182
# Epoch:  44 iteration 0 loss: 2.1538124084472656
# Epoch:  44 iteration 100 loss: 1.9385558366775513
# Epoch:  44 iteration 200 loss: 1.7748756408691406
# Epoch:  45 iteration 0 loss: 2.086622714996338
# Epoch:  45 iteration 100 loss: 2.0171074867248535
# Epoch:  45 iteration 200 loss: 1.7908265590667725
# Epoch:  46 iteration 0 loss: 2.052217960357666
# Epoch:  46 iteration 100 loss: 1.929146647453308
# Epoch:  46 iteration 200 loss: 1.7515252828598022
# Epoch:  47 iteration 0 loss: 2.0643367767333984
# Epoch:  47 iteration 100 loss: 1.9444421529769897
# Epoch:  47 iteration 200 loss: 1.7356375455856323
# Epoch:  48 iteration 0 loss: 2.0051467418670654
# Epoch:  48 iteration 100 loss: 1.9486563205718994
# Epoch:  48 iteration 200 loss: 1.7598077058792114
# Epoch:  49 iteration 0 loss: 1.9981368780136108
# Epoch:  49 iteration 100 loss: 1.9275693893432617
# Epoch:  49 iteration 200 loss: 1.7753220796585083
# Epoch:  50 iteration 0 loss: 2.0019948482513428
# Epoch:  50 iteration 100 loss: 1.9201630353927612
# Epoch:  50 iteration 200 loss: 1.7570030689239502
# Epoch:  51 iteration 0 loss: 1.9970647096633911
# Epoch:  51 iteration 100 loss: 1.9096248149871826
# Epoch:  51 iteration 200 loss: 1.675970435142517
# Epoch:  52 iteration 0 loss: 1.9587516784667969
# Epoch:  52 iteration 100 loss: 1.9168164730072021
# Epoch:  52 iteration 200 loss: 1.7150189876556396
# Epoch:  53 iteration 0 loss: 1.9532617330551147
# Epoch:  53 iteration 100 loss: 1.8586769104003906
# Epoch:  53 iteration 200 loss: 1.7157173156738281
# Epoch:  54 iteration 0 loss: 1.9513696432113647
# Epoch:  54 iteration 100 loss: 1.832871675491333
# Epoch:  54 iteration 200 loss: 1.6791248321533203
# Epoch:  55 iteration 0 loss: 1.9614806175231934
# Epoch:  55 iteration 100 loss: 1.8545023202896118
# Epoch:  55 iteration 200 loss: 1.6705729961395264
# Epoch:  56 iteration 0 loss: 1.9742896556854248
# Epoch:  56 iteration 100 loss: 1.845387578010559
# Epoch:  56 iteration 200 loss: 1.6854369640350342
# Epoch:  57 iteration 0 loss: 1.9436359405517578
# Epoch:  57 iteration 100 loss: 1.8170850276947021
# Epoch:  57 iteration 200 loss: 1.6452757120132446
# Epoch:  58 iteration 0 loss: 1.9356184005737305
# Epoch:  58 iteration 100 loss: 1.8132253885269165
# Epoch:  58 iteration 200 loss: 1.6346346139907837
# Epoch:  59 iteration 0 loss: 1.887229323387146
# Epoch:  59 iteration 100 loss: 1.7904224395751953
# Epoch:  59 iteration 200 loss: 1.639485239982605
# Epoch:  60 iteration 0 loss: 1.9149278402328491
# Epoch:  60 iteration 100 loss: 1.784754991531372
# Epoch:  60 iteration 200 loss: 1.5457394123077393
# Epoch:  61 iteration 0 loss: 1.8883724212646484
# Epoch:  61 iteration 100 loss: 1.813740611076355
# Epoch:  61 iteration 200 loss: 1.6242523193359375
# Epoch:  62 iteration 0 loss: 1.9517444372177124
# Epoch:  62 iteration 100 loss: 1.7891725301742554
# Epoch:  62 iteration 200 loss: 1.567494511604309
# Epoch:  63 iteration 0 loss: 1.857905626296997
# Epoch:  63 iteration 100 loss: 1.7396115064620972
# Epoch:  63 iteration 200 loss: 1.561428427696228
# Epoch:  64 iteration 0 loss: 1.8569713830947876
# Epoch:  64 iteration 100 loss: 1.7493720054626465
# Epoch:  64 iteration 200 loss: 1.5741747617721558
# Epoch:  65 iteration 0 loss: 1.8971996307373047
# Epoch:  65 iteration 100 loss: 1.7043248414993286
# Epoch:  65 iteration 200 loss: 1.5698562860488892
# Epoch:  66 iteration 0 loss: 1.8794002532958984
# Epoch:  66 iteration 100 loss: 1.7357639074325562
# Epoch:  66 iteration 200 loss: 1.5798038244247437
# Epoch:  67 iteration 0 loss: 1.8558349609375
# Epoch:  67 iteration 100 loss: 1.7010093927383423
# Epoch:  67 iteration 200 loss: 1.5685718059539795
# Epoch:  68 iteration 0 loss: 1.8127033710479736
# Epoch:  68 iteration 100 loss: 1.7146211862564087
# Epoch:  68 iteration 200 loss: 1.5280755758285522
# Epoch:  69 iteration 0 loss: 1.8275662660598755
# Epoch:  69 iteration 100 loss: 1.7503160238265991
# Epoch:  69 iteration 200 loss: 1.552184820175171
# Epoch:  70 iteration 0 loss: 1.8016531467437744
# Epoch:  70 iteration 100 loss: 1.7111505270004272
# Epoch:  70 iteration 200 loss: 1.5141252279281616
# Epoch:  71 iteration 0 loss: 1.8122386932373047
# Epoch:  71 iteration 100 loss: 1.6977618932724
# Epoch:  71 iteration 200 loss: 1.4977829456329346
# Epoch:  72 iteration 0 loss: 1.7915035486221313
# Epoch:  72 iteration 100 loss: 1.6497149467468262
# Epoch:  72 iteration 200 loss: 1.4978629350662231
# Epoch:  73 iteration 0 loss: 1.7696260213851929
# Epoch:  73 iteration 100 loss: 1.691487431526184
# Epoch:  73 iteration 200 loss: 1.4906940460205078
# Epoch:  74 iteration 0 loss: 1.7906973361968994
# Epoch:  74 iteration 100 loss: 1.652506709098816
# Epoch:  74 iteration 200 loss: 1.4840904474258423
# Epoch:  75 iteration 0 loss: 1.8152306079864502
# Epoch:  75 iteration 100 loss: 1.6746253967285156
# Epoch:  75 iteration 200 loss: 1.4625442028045654
# Epoch:  76 iteration 0 loss: 1.8107296228408813
# Epoch:  76 iteration 100 loss: 1.6719802618026733
# Epoch:  76 iteration 200 loss: 1.497271180152893
# Epoch:  77 iteration 0 loss: 1.7703052759170532
# Epoch:  77 iteration 100 loss: 1.643865942955017
# Epoch:  77 iteration 200 loss: 1.4778046607971191
# Epoch:  78 iteration 0 loss: 1.7328325510025024
# Epoch:  78 iteration 100 loss: 1.6501258611679077
# Epoch:  78 iteration 200 loss: 1.4686371088027954
# Epoch:  79 iteration 0 loss: 1.7589542865753174
# Epoch:  79 iteration 100 loss: 1.618983507156372
# Epoch:  79 iteration 200 loss: 1.4792417287826538
# Epoch:  80 iteration 0 loss: 1.74961519241333
# Epoch:  80 iteration 100 loss: 1.6366925239562988
# Epoch:  80 iteration 200 loss: 1.4610298871994019
# Epoch:  81 iteration 0 loss: 1.7188138961791992
# Epoch:  81 iteration 100 loss: 1.6252174377441406
# Epoch:  81 iteration 200 loss: 1.4575358629226685
# Epoch:  82 iteration 0 loss: 1.727469801902771
# Epoch:  82 iteration 100 loss: 1.6067864894866943
# Epoch:  82 iteration 200 loss: 1.4338170289993286
# Epoch:  83 iteration 0 loss: 1.7469217777252197
# Epoch:  83 iteration 100 loss: 1.6283270120620728
# Epoch:  83 iteration 200 loss: 1.3873134851455688
# Epoch:  84 iteration 0 loss: 1.7226802110671997
# Epoch:  84 iteration 100 loss: 1.6394920349121094
# Epoch:  84 iteration 200 loss: 1.4317885637283325
# Epoch:  85 iteration 0 loss: 1.7216850519180298
# Epoch:  85 iteration 100 loss: 1.5903505086898804
# Epoch:  85 iteration 200 loss: 1.4264321327209473
# Epoch:  86 iteration 0 loss: 1.6597785949707031
# Epoch:  86 iteration 100 loss: 1.542894721031189
# Epoch:  86 iteration 200 loss: 1.3799653053283691
# Epoch:  87 iteration 0 loss: 1.7031666040420532
# Epoch:  87 iteration 100 loss: 1.5626254081726074
# Epoch:  87 iteration 200 loss: 1.425851583480835
# Epoch:  88 iteration 0 loss: 1.6205220222473145
# Epoch:  88 iteration 100 loss: 1.5617284774780273
# Epoch:  88 iteration 200 loss: 1.38485848903656
# Epoch:  89 iteration 0 loss: 1.7126277685165405
# Epoch:  89 iteration 100 loss: 1.5487606525421143
# Epoch:  89 iteration 200 loss: 1.3480567932128906
# Epoch:  90 iteration 0 loss: 1.6589527130126953
# Epoch:  90 iteration 100 loss: 1.5683881044387817
# Epoch:  90 iteration 200 loss: 1.3731107711791992
# Epoch:  91 iteration 0 loss: 1.7367416620254517
# Epoch:  91 iteration 100 loss: 1.5757085084915161
# Epoch:  91 iteration 200 loss: 1.374631643295288
# Epoch:  92 iteration 0 loss: 1.6900924444198608
# Epoch:  92 iteration 100 loss: 1.522195816040039
# Epoch:  92 iteration 200 loss: 1.3291471004486084
# Epoch:  93 iteration 0 loss: 1.6583080291748047
# Epoch:  93 iteration 100 loss: 1.547494888305664
# Epoch:  93 iteration 200 loss: 1.3272899389266968
# Epoch:  94 iteration 0 loss: 1.6904362440109253
# Epoch:  94 iteration 100 loss: 1.5580923557281494
# Epoch:  94 iteration 200 loss: 1.3630411624908447
# Epoch:  95 iteration 0 loss: 1.6452815532684326
# Epoch:  95 iteration 100 loss: 1.4943205118179321
# Epoch:  95 iteration 200 loss: 1.345668077468872
# Epoch:  96 iteration 0 loss: 1.6933479309082031
# Epoch:  96 iteration 100 loss: 1.5248489379882812
# Epoch:  96 iteration 200 loss: 1.3389935493469238
# Epoch:  97 iteration 0 loss: 1.6346385478973389
# Epoch:  97 iteration 100 loss: 1.5234853029251099
# Epoch:  97 iteration 200 loss: 1.3532946109771729
# Epoch:  98 iteration 0 loss: 1.6608915328979492
# Epoch:  98 iteration 100 loss: 1.4851950407028198
# Epoch:  98 iteration 200 loss: 1.3292667865753174
# Epoch:  99 iteration 0 loss: 1.6241792440414429
# Epoch:  99 iteration 100 loss: 1.5211760997772217
# Epoch:  99 iteration 200 loss: 1.2457952499389648
